# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5,6,7]
y=[32,34,56,78,23,45,64]

# %%
plt.plot(x,y,color='black',linewidth=5)
plt.xlabel('day')
plt.ylabel('weather')
plt.title('weather')
# Out:
# Text(0.5, 1.0, 'weather')
