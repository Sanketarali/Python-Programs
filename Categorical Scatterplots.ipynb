# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('tips.csv')

# %%
df.head()
# Out:
#    Total_bill   Tip     Sex Smoker  Day    Time  Size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x='Day' , y='Tip', kind='strip' , data =df)

# %%
sns.catplot(x='Day' , y='Tip', kind='swarm' , data =df)
# Out:
# C:\Users\Sanket\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x='Day' , y='Tip', kind='strip' ,hue='Sex' , data =df)

# %%
sns.swarmplot(x='Day' , y='Tip',   data =df)
# Out:
# C:\Users\Sanket\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Sanket\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Day', ylabel='Tip'>
